# %%
import sys
import os

CARTOLA_HOME = os.path.abspath('..')

if not os.path.isdir(CARTOLA_HOME):
    raise Exception('Cartola project is missing!')
    
sys.path.append(CARTOLA_HOME)

# %%
from cartola_game.data import load_season

season_2015 = load_season('2015')

print(season_2015)
# Out:
# 2015 (rounds 38, players 1041)

# %%
from cartola_game.model import Team, Formation, Player, Position, team_is_valid

# %%
valid_team = [Player('a', Position.GOALKEEPER)]
valid_team += [Player('d {}'.format(i+1), Position.DEFENDER) for i in range(3)]
valid_team += [Player('m {}'.format(i+1), Position.MIDFIELDER) for i in range(4)]
valid_team += [Player('f {}'.format(i+1), Position.FORWARD) for i in range(3)]
valid_team += [Player('e', Position.COACH)]

team_is_valid(Formation.F343, valid_team)
# Out:
# True

# %%
from collections import namedtuple

PlayerState = namedtuple('PlayerState', ['player', 'status', 'price', 'price_var', 'score'])

class RoundEngine:
    
    def __init__(self, round_number, players_data):
        self.round_number = round_number
        self.players_data = players_data

    def price(self, players):
        return sum(self.players_data[p].price for p in players)

class ScoreEngine:
    
    def __init__(self, players_score):
        self.players_score = players_score

    def score(self, players):
        return sum(self.players_score[p] for p in players)

class GameEngine:
    
    def __init__(self, season_data):
        rounds = []
        scores = []
        
        for i in range(season_data.num_rounds):
            round_players = {}
            score_players = {}
            for player_data in season_data.players:
                p = player_data.player
                round_players[p] = self._round_player(player_data, i)
                score_players[p] = self._score_player(player_data, i)
            rounds.append(RoundEngine(i + 1, round_players))
            scores.append(ScoreEngine(score_players))
        
        self.rounds = rounds
        self.scores = scores
    
    def _round_player(self, player_data, i):
        player = player_data.player
        status = player_data.status[i]
        price = player_data.prices[i]
        price_var = 0.0 if i == 0 else price - player_data.prices[i - 1]
        score = 0.0 if i == 0 else player_data.scores[i - i]
        return PlayerState(player, status, price, price_var, score)
    
    def _score_player(self, player_data, i):
        return player_data.scores[i]
    
    @property
    def num_rounds(self):
        return len(self.rounds)
    
    def round_engine(self, round_number):
        return self.rounds[round_number - 1]

    def score_engine(self, round_number):
        return self.scores[round_number - 1]

class GameState(namedtuple('GameState', ['round_number', 'team', 'team_price', 'team_score', 'money'])):
    __slots__ = ()

    def __str__(self):
        out = '[ Round {} ]\n\n'.format(self.round_number)
        out += str(self.team)
        out += '\n\nTeam Price: {:.2f}\n'.format(self.team_price)
        out += 'Unused Money: {:.2f}\n\n'.format(self.money)
        out += 'Score: {:.2f}'.format(self.team_score)
        return out

class GameInstance:
    
    def __init__(self, engine, initial_money=100.0):
        self.engine = engine
        self.initial_money = initial_money
        self.states = []

    @property
    def done(self):
        return len(self.states) == self.engine.num_rounds
    
    @property
    def round_number(self):
        return len(self.states) + 1
    
    @property
    def data(self):
        return self.engine.round_engine(self.round_number - int(self.done))
    
    @property
    def total_money(self):
        if self.round_number == 1:
            return self.initial_money
        s = self.states[-1]
        return s.money + self.data.price(s.team.players)
    
    def run(self, team):
        if self.done:
            raise Exception('Game is done!')

        running_round = self.round_number

        budget = self.total_money
        team_price = self.data.price(team.players)
        free_money = budget - team_price
        if free_money < 0.0:
            raise Exception('Invalid team: insufficient budget!')

        team_score = self.engine.score_engine(running_round).score(team.players)

        s = GameState(running_round, team, team_price, team_score, free_money)
        self.states.append(s)

        return team_score

# %%
x = GameEngine(season_2015)

# %%
import random

def filter_players(players, position, max_price):
    return [p for p in players if p.player.position == position and p.price < max_price]

def sample_players(players, formation, budget):
    selected_players = []
    for pos, n in formation.positions:
        candidates = filter_players(players, pos, budget)
        if len(candidates) < n:
            return None
        for player in random.sample(candidates, n):
            budget -= player.price
            if budget < 0.0:
                return None
            selected_players.append(player.player)
    return selected_players
    
def random_team(data, budget, max_iterations=1000000):
    players_list = list(data.players_data.values())
    for _ in range(max_iterations):
        formation = random.choice(list(Formation))
        players = sample_players(players_list, formation, budget)
        if not players:
            continue
        return Team(formation, players)
    return None

data = x.round_engine(1)
team = random_team(data, 100.0)
print(team)
print('\nPrice: {:.2f}'.format(data.price(team.players)))
# Out:
# 4-3-3
#
# Goleiro -> Nelson de Jesus Silva
# Lateral -> Ayrton Luis Ganino
# Lateral -> Erick Fernando Brandão Daltro
# Zagueiro -> Felipe Augusto de Almeida Monteiro
# Zagueiro -> Nathan Pelae Cardoso
# Meia -> Jhon Cley Jesus Silva
# Meia -> Jonatan Lucca
# Meia -> Sergio Antonio Soler de Oliveira Junior
# Atacante -> Bruno Rangel Domingues
# Atacante -> Lucca Borges Brito
# Atacante -> Ruan Carlos Gomes Costa da Silva
# Técnico -> Paulo Roberto Falcão
#
# Price: 49.00

# %%
i = GameInstance(x)

t_score = 0.0
while not i.done:
    print('[ Round', i.round_number, ']\n')
    data = i.data
    budget = i.total_money
    team = random_team(data, budget)
    
    print(team)
    team_value = data.price(team.players)
    print('\nTeam Price: {:.2f}'.format(team_value))
    print('Unused Money: {:.2f}'.format(budget - team_value))
    
    score = i.run(team)
    t_score += score
    
    print('\nScore: {:.2f}'.format(score))
    after_money = i.total_money
    print('Money: {:.2f}'.format(after_money))
    print('Variation: {:.2f}\n'.format(after_money - budget))

print('...')
print('\nFinal Score: {:.2f}'.format(t_score))
# Out:
# [ Round 1 ]
#
# 4-4-2
#
# Goleiro -> Jordi Almeida
# Lateral -> Francisco Sousa dos Santos
# Lateral -> Renê Rodrigues Martins
# Zagueiro -> Antônio Carlos dos Santos Aguiar
# Zagueiro -> Douglas Ricardo Grolli
# Meia -> Juliano Real Pacheco
# Meia -> Rudnei da Rosa
# Meia -> Sandro Laurindo da Silva
# Meia -> Ítalo Melo Oliveira
# Atacante -> Everaldo Stum
# Atacante -> José Fagner Silva da Luz
# Técnico -> Sergio Agostinho de Oliveira Vieira
#
# Team Price: 44.57
# Unused Money: 55.43
#
# Score: -6.80
# Money: 99.18
# Variation: -0.82
#
# [ Round 2 ]
#
# 5-3-2
#
# Goleiro -> Vitor Prada Macaneiro
# Lateral -> Daniel Borges Fortunato
# Lateral -> João Lucas Lima Silva
# Zagueiro -> Henrique de Souza Trevisan
# Zagueiro -> Rafael Marques Pinto
# Zagueiro -> Rodrigo Modesto da Silva Moledo
# Meia -> Icaro Cosmo da Rocha
# Meia -> Wagner Ricardo Silva da Silva
# Meia -> Yuri Naves Roberto
# Atacante -> Jonathan Renato Barbosa
# Atacante -> William Júnior Salles de Lima Souza
# Técnico -> Argélico Fucks
#
# Team Price: 22.97
# Unused Money: 76.21
#
# Score: 6.62
# Money: 99.43
# Variation: 0.25
#
# [ Round 3 ]
#
# 3-4-3
#
# Goleiro -> Matheus Phillipe Coutinho Gomes
# Zagueiro -> Philipe Maia de Freitas
# Zagueiro -> Victor Oliveira
# Zagueiro -> Wagner da Silva
# Meia -> José Gildeixon Clemente Paiva
# Meia -> Maximiliano Rodríguez
# Meia -> Pedro Ken Morimoto Moreira
# Meia -> Teodoro Junio Barbosa de Araújo
# Atacante -> Jael Ferreira Vieira
# Atacante -> José Fagner Silva da Luz
# Atacante -> Leandro Damião da Silva dos Santos
# Técnico -> Jayme de Almeida Filho
#
# Team Price: 70.38
# Unused Money: 29.05
#
# Score: 0.20
# Money: 99.47
# Variation: 0.04
#
# [ Round 4 ]
#
# 5-3-2
#
# Goleiro -> Leonardo Cesar Jardim
# Lateral -> José Carlos Cracco Neto
# Lateral -> Leonardo Pinheiro da Conceição
# Zagueiro -> David de Duarte Macedo
# Zagueiro -> Rodrigo Baldasso da Costa
# Zagueiro -> Rodrigo Eduardo da Silva
# Meia -> João Afonso Crispim
# Meia -> Lucas Machado Pinna
# Meia -> Wellington Wildy Muniz dos Santos
# Atacante -> Bruno Pereira Mendes
# Atacante -> Iury Lirio Freitas de Castilho
# Técnico -> Alberto Valentim do Carmo Neto
#
# Team Price: 48.44
# Unused Money: 51.03
#
# Score: 0.70
# Money: 101.04
# Variation: 1.57
#
# [ Round 5 ]
#
# 4-5-1
#
# Goleiro -> Elisson Aparecido Rosa
# Lateral -> Ayrton Lucas Dantas de Medeiros
# Lateral -> Francisco Sousa dos Santos
# Zagueiro -> Augusto de Souza Silva
# Zagueiro -> Paulo André Cren Benini
# Meia -> Bernardo Vieira de Souza
# Meia -> Fernando Paixão da Silva
# Meia -> José Paulo de Oliveira Pinto
# Meia -> Matheus Pereira da Silva
# Meia -> Rafael Diniz Alves e Silva
# Atacante -> Diego Queiroz de Oliveira
# Técnico -> Argélico Fucks
#
# Team Price: 64.96
# Unused Money: 36.08
#
# Score: 16.65
# Money: 98.91
# Variation: -2.13
#
# [ Round 6 ]
#
# 5-3-2
#
# Goleiro -> Thiago Rodrigues da Silva
# Lateral -> Junio Ricardo da Rocha
# Lateral -> Matheus Oliveira de Souza
# Zagueiro -> Denilson dos Santos de Souza
# Zagueiro -> Marcos Roberto da Silva Barbosa
# Zagueiro -> Wallace Reis da Silva
# Meia ->  João Pedro Heinen Silva
# Meia -> Erivonaldo Florencio de Oliveira Filho
# Meia -> Ítalo Melo Oliveira
# Atacante -> Braian Damián Rodríguez Carballo
# Atacante -> Márcio Passos de Albuquerque
# Técnico -> James Freitas
#
# Team Price: 59.03
# Unused Money: 39.88
#
# Score: 4.00
# Money: 101.77
# Variation: 2.86
#
# [ Round 7 ]
#
# 3-5-2
#
# Goleiro -> Rafael Copetti Fernandes
# Zagueiro -> Gabriel Costa França
# Zagueiro -> Jemerson de Jesus Nascimento
# Zagueiro -> Luiz Eduardo Rodrigues
# Meia -> Deivid Willian da Silva
# Meia -> Lucas Cândido Silva
# Meia -> Matteus Oliveira Santos
# Meia -> Thiago dos Santos
# Meia -> Wellington Wildy Muniz dos Santos
# Atacante -> Alexandre Rodrigues da Silva
# Atacante -> Jarlan Pinheiro da Silva
# Técnico -> Raul Cabral
#
# Team Price: 65.86
# Unused Money: 49.64
#
# Score: 1.70
# Money: 116.15
# Variation: 0.65
#
# [ Round 17 ]
#
# 3-5-2
#
# Goleiro -> Jordi Almeida
# Zagueiro -> Cássio Alessandro de Souza
# Zagueiro -> Frederico Burgel Xavier
# Zagueiro -> Henrique Mendonça Mattos
# Meia -> Cicero Clebson Alves Santana
# Meia -> Giovanni Piccolomo
# Meia -> Jadson Rodrigues da Silva
# Meia -> Jefferson Nogueira Junior
# Meia -> Rafael Gimenes da Silva
# Atacante -> Jarlan Pinheiro da Silva
# Atacante -> Wallace Lucas Aires da Silva
# Técnico -> Cristóvão Borges dos Santos
#
# Team Price: 59.37
# Unused Money: 56.78
#
# Score: 4.12
# Money: 118.38
# Variation: 2.23
#
# [ Round 18 ]
#
# 5-3-2
#
# Goleiro -> Rafael Copetti Fernandes
# Lateral -> Fabiano Leissmann
# Lateral -> Leonardo Rodrigues
# Zagueiro -> Aislan Paulo Lotici Back
# Zagueiro -> Jesiel Cardoso Miranda
# Zagueiro -> Leonardo Fabiano da Silva e Silva
# Meia -> Danilo das Neves Pinheiro
# Meia -> Ronaldo da Silva Souza
# Meia -> Uelliton da Silva Vieira
# Atacante -> Ricardo Bueno da Silva
# Atacante -> Robson de Souza
# Técnico -> Hemerson Maria
#
# Team Price: 70.61
# Unused Money: 47.77
#
# Score: -0.90
# Money: 117.30
# Variation: -1.08
#
# [ Round 19 ]
#
# 4-4-2
#
# Goleiro -> Jhonatan Luiz da Siqueira
# Lateral -> Carlos Andrade Souza
# Lateral -> Willian de Asevedo Furtado
# Zagueiro -> Joemison Santos Barbosa
# Zagueiro -> Matheus Ferraz Pereira
# Meia -> Antônio Francisco Moura Neto
# Meia -> Paulo César Fonseca do Nascimento
# Meia -> Paulo Henrique Dias da Cruz
# Meia -> Renato Escobar Baruffi
# Atacante -> Fábio Souza dos Santos
# Atacante -> Rafael Martiniano de Miranda Moura
# Técnico -> Eduardo Augusto Baptista Miguel
#
# Team Price: 78.89
# Unused Money: 38.41
#
# Score: 16.65
# Money: 118.19
# Variation: 0.89
#
# [ Round 20 ]
#
# 5-3-2
#
# Goleiro -> Marcos Felipe de Freitas Monteiro
# Lateral -> Lucas Ramon Batista da Silva
# Lateral -> Malcoon Silva
# Zagueiro -> Bruno Rodrigo Fenelon Palomo
# Zagueiro -> Leandro Almeida da Silva
# Zagueiro -> Leandro Paulino da Silva
# Meia -> Jhon Cley Jesus Silva
# Meia -> Patrick Bezerra do Nascimento
# Meia -> Wesley Lopes Beltrame
# Zagueiro -> Jecimauro José Borges dos Santos
# Zagueiro -> Marcelo Augusto Mathias da Silva
# Meia -> Bruno César Pereira da Silva
# Meia -> Cristian Martins Cabral
# Meia -> Francisco Edson Moreira da Silva
# Meia -> Lucas Machado Pinna
# Meia -> Rubens Raimundo da Silva
# Atacante -> Henrique Almeida Caixeta Nascentes
# Atacante -> Romulo dos Santos de Souza
# Técnico -> Hudson José Coutinho
#
# Team Price: 56.30
# Unused Money: 65.67
#
# Score: 9.60
# Money: 126.74
# Variation: 4.77
#
# [ Round 26 ]
#
# 4-5-1
#
# Goleiro -> Bruno Medeiros Grassi
# Lateral -> Carlos Andrade Souza
# Lateral -> Everton José Modesto Silva
# Zagueiro -> Eberson Silva de Pontes
# Zagueiro -> Manoel Messias Silva Carvalho
# Meia -> Claudinei Junio De Souza
# Meia -> Fernando Paixão da Silva
# Meia -> Hudson Rodrigues dos Santos
# Meia -> Matheus de Sales Cabral
# Meia -> Renato Augusto Santos Junior
# Atacante -> Matheus Gonçalves Sávio
# Técnico -> Marcelo de Oliveira Santos
#
# Team Price: 67.47
# Unused Money: 59.27
#
# Score: 14.41
# Money: 128.25
# Variation: 1.51
#
# [ Round 27 ]
#
# 4-5-1
#
# Goleiro -> Wilson Rodrigues de Moura Júnior
# Lateral -> Artur Sérgio Batista de Souza
# Lateral -> Emerson da Conceição
# Zagueiro -> Ednei Barbosa de Souza
# Zagueiro -> Victor Ramos Ferreira
# Meia -> Cicero Clebson Alves Santana
# Meia -> Danilo Pires Costa
# Meia -> Felipe Tontini da Silveira
# Meia -> Otávio Henrique Passos Santos
# Meia -> Péricles da Silva Nunes
# Atacante -> Luciano da Rocha Neves
# Técnico -> Claudiomiro Salenave Santiago
#
# Team Price: 55.99
# Unused Money: 72.26
#
# Score: 10.40
# Money: 127.16
# Variation: -1.09
#
# [ Round 28 ]
#
# 4-4-2
#
# Goleiro -> Renan Brito Soares
# Lateral -> Eron Santos Lourenço
# Lateral -> José Roberto da Silva Júnior
# Zagueiro -> Thiago Carvalho de Oliveira
# Zagueiro -> Victor Oliveira
# Meia -> David França Oliveira e Silva
# Meia -> Diogo Henrique Sodré
# Meia -> Leonardo Cittadini
# Meia -> Ryder Matos Santos
# Atacante -> Bruno Pereira Mendes
# Atacante -> Magno Alves de Araújo
# Técnico -> Milton Mendes
#
# Team Price: 89.53
# Unused Money: 37.63
#
# Score: -0.06
# Money: 126.81
# Variation: -0.35
#
# [ Round 29 ]
#
# 5-3-2
#
# Goleiro -> Mário Lúcio Duarte Costa
# Lateral -> Anderson da Silveira Ribeiro
# Lateral -> Wellington do Nascimento Silva
# Zagueiro -> Dankler Luis de Jesus Pedreira
# Zagueiro -> Felipe Augusto de Almeida Monteiro
# Zagueiro -> Juan Silveira dos Santos
# Meia -> Ederson Honorato Campos
# Meia -> Luan José Niedzielsk
# Meia -> Santiago Montoya Muñoz
# Atacante -> Edigar Junio Teixeira Lima
# Atacante -> José Rogério de Oliveira
# Técnico -> Argélico Fucks
#
# Meia -> Hudson Rodrigues dos Santos
# Meia -> Hugo Gomes dos Santos Silva
# Meia -> Willians Domingos Fernandes
# Atacante -> Carlos Eduardo Ferreira de Souza
# Atacante -> Rafael Marques Mariano
# Técnico -> Jayme de Almeida Filho
#
# Team Price: 106.36
# Unused Money: 15.64
#
# Score: 16.60
# Money: 120.56
# Variation: -1.44
#
# [ Round 35 ]
#
# 3-5-2
#
# Goleiro -> Thiago Rodrigues da Silva
# Zagueiro -> Douglas da Silva
# Zagueiro -> Eduardo Luís Abonizio de Souza
# Zagueiro -> Felipe Francisco Macedo
# Meia -> Carlos Martín Luque
# Meia -> Francinilson Santos Meireles
# Meia -> Marcos Gabriel do Nascimento
# Meia -> Ricardo Souza Silva
# Meia -> Silas Araújo da Silva
# Atacante -> Bruno Henrique Baio da Cunha
# Atacante -> Paulo Conrado do Carmo Sardin
# Técnico -> Felipe José Feres Moreira
#
# Team Price: 70.75
# Unused Money: 49.81
#
# Score: 0.35
# Money: 120.40
# Variation: -0.16
#
# [ Round 36 ]
#
# 4-5-1
#
# Goleiro -> Reynaldo Moura Machado dos Santos
# Lateral -> Mário Sérgio Gomes de Souza
# Lateral -> Wesley Craudio Campos
# Zagueiro -> Ernando Rodrigues Lopes
# Zagueiro -> Jonathan Doin
# Meia -> Charles Fernando Basílio da Silva
# Meia -> Gabriel Girotto Franco
# Meia -> Harrison Cardoso de Oliveira
# Meia -> Jaílson Marques Siqueira
# Meia -> Paulo César Fonseca do Nascimento
# Atacante -> Marcos do Sul Bezerra
# Técnico -> Hemerson Maria
#
# Team Price: 69.11
# Unused Money: 51.29
#
# Score: 3.00
# Money: 121.76
# Variation: 1.36
#
# [ Round 37 ]
#
# 4-5-1
#
# Goleiro -> Caique França Godoy
# Lateral -> Lucas Taylor Maia Reis
# Lateral -> Weverton Almeida Santos
# Zagueiro -> Leonardo Fabiano da Silva e Silva
# Zagueiro -> Leonardo José Aparecido de Moura
# Meia -> Alan Santos da Silva
# Meia -> Charles Mariano Aránguiz Sandoval
# Meia -> Matheus Bitencourt da Silva
# Meia -> Matheus Trindade Gonçalves
# Meia -> Ramiro Moschen Benetti
# Atacante -> Danilo Lopes Cezário
# Técnico -> Augusto César
#
# Team Price: 81.58
# Unused Money: 40.18
#
# Score: 8.50
# Money: 124.14
# Variation: 2.38
#
# [ Round 38 ]
#
# 4-5-1
#
# Goleiro -> Marcelo Grohe
# Lateral -> Kevin Peterson Dos Santos Silva
# Lateral -> Marcos Venâncio de Albuquerque
# Zagueiro -> Leonardo José Aparecido de Moura
# Zagueiro -> Welinton Souza Silva
# Meia -> Alisson Alves Farias
# Meia -> Rafael Vinicius Carvalho Longuine
# Meia -> Rodrigo Dourado Cunha
# Meia -> Rodrigo Eduardo Costa Marinho
# Meia -> Uillian Correia Granemann
# Atacante -> Malcom Filipe Silva de Oliveira
# Técnico -> Raul Cabral
#
# Team Price: 78.08
# Unused Money: 46.06
#
# Score: 11.91
# Money: 124.14
# Variation: 0.00
#
# ...
#
# Final Score: 291.27
